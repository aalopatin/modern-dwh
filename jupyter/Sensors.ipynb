# %%
# %run ./common/spark-session.ipynb
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/21 04:42:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# %%sparksql
# CREATE NAMESPACE bronze;

# %%
# %%sparksql
# CREATE NAMESPACE bronze.kafka;

# %%
# %%sparksql
# SELECT * FROM bronze.kafka.sensors
# Out:
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">id</td><td style="font-weight: bold">measurements_timestamp</td><td style="font-weight: bold">measurements</td></tr><tr><td>TH0101</td><td>2025-08-21 04:28:32.789000</td><td>[Row(name=&#x27;temperature&#x27;, value=22.0), Row(name=&#x27;humidity&#x27;, value=55.1)]</td></tr><tr><td>T0102</td><td>2025-08-21 04:28:32.797000</td><td>[Row(name=&#x27;temperature&#x27;, value=20.3)]</td></tr><tr><td>H0102</td><td>2025-08-21 04:28:32.808000</td><td>[Row(name=&#x27;humidity&#x27;, value=38.3)]</td></tr><tr><td>TH0101</td><td>2025-08-21 04:28:42.794000</td><td>[Row(name=&#x27;temperature&#x27;, value=22.4), Row(name=&#x27;humidity&#x27;, value=54.8)]</td></tr><tr><td>T0102</td><td>2025-08-21 04:28:42.803000</td><td>[Row(name=&#x27;temperature&#x27;, value=20.0)]</td></tr><tr><td>H0102</td><td>2025-08-21 04:28:42.815000</td><td>[Row(name=&#x27;humidity&#x27;, value=38.6)]</td></tr><tr><td>TH0101</td><td>2025-08-21 04:28:52.849000</td><td>[Row(name=&#x27;temperature&#x27;, value=22.4), Row(name=&#x27;humidity&#x27;, value=55.2)]</td></tr><tr><td>T0102</td><td>2025-08-21 04:28:52.858000</td><td>[Row(name=&#x27;temperature&#x27;, value=20.2)]</td></tr><tr><td>H0102</td><td>2025-08-21 04:28:52.869000</td><td>[Row(name=&#x27;humidity&#x27;, value=38.8)]</td></tr><tr><td>TH0101</td><td>2025-08-21 04:29:02.855000</td><td>[Row(name=&#x27;temperature&#x27;, value=22.6), Row(name=&#x27;humidity&#x27;, value=55.1)]</td></tr><tr><td>T0102</td><td>2025-08-21 04:29:02.864000</td><td>[Row(name=&#x27;temperature&#x27;, value=20.2)]</td></tr><tr><td>H0102</td><td>2025-08-21 04:29:02.874000</td><td>[Row(name=&#x27;humidity&#x27;, value=38.7)]</td></tr><tr><td>TH0101</td><td>2025-08-21 04:29:12.862000</td><td>[Row(name=&#x27;temperature&#x27;, value=23.0), Row(name=&#x27;humidity&#x27;, value=55.4)]</td></tr><tr><td>T0102</td><td>2025-08-21 04:29:12.869000</td><td>[Row(name=&#x27;temperature&#x27;, value=20.2)]</td></tr><tr><td>H0102</td><td>2025-08-21 04:29:12.879000</td><td>[Row(name=&#x27;humidity&#x27;, value=39.1)]</td></tr><tr><td>TH0101</td><td>2025-08-21 04:29:22.919000</td><td>[Row(name=&#x27;temperature&#x27;, value=23.2), Row(name=&#x27;humidity&#x27;, value=55.2)]</td></tr><tr><td>T0102</td><td>2025-08-21 04:29:22.925000</td><td>[Row(name=&#x27;temperature&#x27;, value=20.0)]</td></tr><tr><td>H0102</td><td>2025-08-21 04:29:22.933000</td><td>[Row(name=&#x27;humidity&#x27;, value=38.9)]</td></tr><tr><td>TH0101</td><td>2025-08-21 04:29:32.927000</td><td>[Row(name=&#x27;temperature&#x27;, value=23.5), Row(name=&#x27;humidity&#x27;, value=55.4)]</td></tr><tr><td>T0102</td><td>2025-08-21 04:29:32.933000</td><td>[Row(name=&#x27;temperature&#x27;, value=20.0)]</td></tr></table>

# %%
print(
    spark
        .table("bronze.kafka.sensors")
        .count()
)
# Out:
# 522211

# %%
(
    spark
        .table("bronze.kafka.sensors")
        .printSchema()
)
# Out:
# root
#  |-- id: string (nullable = false)
#  |-- measurements_timestamp: timestamp (nullable = false)
#  |-- measurements: array (nullable = false)
#  |    |-- element: struct (containsNull = false)
#  |    |    |-- name: string (nullable = false)
#  |    |    |-- value: double (nullable = false)

# %%
# %%sparksql
# SHOW CREATE TABLE bronze.kafka.sensors;
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">createtab_stmt</td></tr><tr><td>CREATE TABLE lakehouse.bronze.kafka.sensors (
#   id STRING NOT NULL,
#   measurements_timestamp TIMESTAMP NOT NULL,
#   measurements ARRAY&lt;STRUCT&lt;name: STRING, value: DOUBLE&gt;&gt; NOT NULL)
# USING iceberg
# PARTITIONED BY (days(measurements_timestamp))
# LOCATION &#x27;s3a://lakehouse/bronze.kafka/sensors_dc6763a9-c7b7-4fa3-a4dd-8baa6af6a29f&#x27;
# TBLPROPERTIES (
#   &#x27;current-snapshot-id&#x27; = &#x27;6352033752291068805&#x27;,
#   &#x27;format&#x27; = &#x27;iceberg/parquet&#x27;,
#   &#x27;format-version&#x27; = &#x27;2&#x27;,
#   &#x27;gc.enabled&#x27; = &#x27;false&#x27;,
#   &#x27;nessie.commit.id&#x27; = &#x27;d2fd08612cb6583bb6892435fa431c8c9ca275d5597adec8d50381197fae6e7c&#x27;,
#   &#x27;write.metadata.delete-after-commit.enabled&#x27; = &#x27;false&#x27;,
#   &#x27;write.parquet.compression-codec&#x27; = &#x27;zstd&#x27;)
# </td></tr></table>

# %% [markdown]
# ```sql
# CREATE TABLE lakehouse.bronze.kafka.sensors (
#     id STRING NOT NULL,
#     measurements_timestamp TIMESTAMP NOT NULL,
#     measurements ARRAY<STRUCT<name: STRING, value: DOUBLE>> NOT NULL
# ) USING iceberg
# PARTITIONED BY (days(measurements_timestamp))
# LOCATION 's3a://lakehouse/bronze.kafka/sensors_dc6763a9-c7b7-4fa3-a4dd-8baa6af6a29f'
# TBLPROPERTIES (
#     'current-snapshot-id' = '6352033752291068805',
#     'format' = 'iceberg/parquet',
#     'format-version' = '2',
#     'gc.enabled' = 'false',
#     'nessie.commit.id' = 'd2fd08612cb6583bb6892435fa431c8c9ca275d5597adec8d50381197fae6e7c',
#     'write.metadata.delete-after-commit.enabled' = 'false',
#     'write.parquet.compression-codec' = 'zstd'
# )
# ```
