# %%
# %run ./common/spark-session.ipynb
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/31 15:37:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# %%sparksql
# CREATE NAMESPACE test;
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# CREATE NAMESPACE test.sub_test;
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# CREATE TABLE test.sub_test.test_table (
#     key INT,
#     value STRING
# )
# USING iceberg;
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# INSERT INTO test.sub_test.test_table VALUES
#     (1, 'one'),
#     (2, 'two'),
#     (3, 'three'),
#     (4, 'four'),
#     (5, 'five');
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
# %%sparksql
# SELECT * FROM test.sub_test.test_table;
